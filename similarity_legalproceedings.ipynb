# %%
# Requried imports
import os
import re
import pandas as pd
from nltk.tokenize import RegexpTokenizer, sent_tokenize
import numpy as np
# Text extraction patterns
#mda_regex = r"item[^a-zA-Z\n]*\d\s*\.\s*management\'s discussion and analysis.*?^\s*item[^a-zA-Z\n]*\d\s*\.*"
#mda_regex = r"item[^a-zA-Z\n]\s*[.:]?\s*LEGAL PROCEEDINGS.*?^\s*item[^a-zA-Z\n]*\d\s*\.*" 2nd BEST
#mda_regex = r"item[^a-zA-Z\n]\s*[\d.:]*\s*LEGAL PROCEEDINGS.*?^\s*item[^a-zA-Z\n]*\d\s*\.*" BEST


#mda_regex = r"item\s?[^a-zA-Z\n][\d.:]*\s*legal proceedings.*?\s*item[^a-zA-Z\n]*\d\s*\.*" #Works for 


mda_regex = r"item\s?[^a-zA-Z\n][\d.:]*\s*.\s*legal proceedings.*?\s*item[^a-zA-Z\n]*\d\s*\.*"


#mda_regex = r"item\s?[^a-zA-Z\n][\d.:]*\s*.\s*management'?s discussion analysis.*?\s*item[^a-zA-Z\n]*\d\s*\.*"




#mda_regex = r"item[]*.\s*LEGAL PROCEEDINGS.*?\s*item[\d]\s\.*"
#qqd_regex = r"item[^a-zA-Z\n]*\d[a-z]?\.?\s*Quantitative and Qualitative Disclosures about " \
 #           r"Market Risk.*?^\s*item\s*\d\s*"
#riskfactor_regex = r"item[^a-zA-Z\n]*\d[a-z]?\.?\s*Risk Factors.*?^\s*item\s*\d\s*"
#legalproc_regex = r"item[^a-zA-Z\n]*\d[a-z]?\.?\s**?^\s*item\s*\d\s*"

# %%
# Function for extracting requried text
def rawdata_extract(path, cikListFile):
    html_regex = re.compile(r'<.*?>') #HTML TAGS
    #extracted_data=[]
    
    df_final = pd.DataFrame()
    cikListFile = pd.read_csv(cikListFile)
    for index, row in cikListFile.iterrows():
        processingFile=row['path'].split('/')
        
        inputFile = processingFile[3]
        #inputFile = str(inputFile).replace('\n', '')
        #print(type(inputFile))
        cik=row['cik']
        coname=row['company']
        #fyrmo=row['FYRMO']
        fdate = row['date']
        #form = row['FORM']
        secfname=row['path']
        for fileName in os.listdir(path):
            
            filenameopen = os.path.join(path, fileName)
            #filenamewrite = os.path.join(output,fileName)
            #dirFileName = filenameopen.split('\\')
            #print(filenameopen)
            #print(dirFileName)
            currentFile=fileName

            if os.path.isfile(filenameopen) and currentFile == inputFile :
                
                resultdict = dict()
                resultdict['cik'] = [cik]
                resultdict['company'] = [coname]
                #resultdict['FYRMO'] = fyrmo
                resultdict['date'] = [fdate]
                #resultdict['FORM'] = form
                resultdict['path'] = [secfname]
                
                with open(filenameopen, 'r', encoding='utf-8', errors="replace") as in_file:
                    content = in_file.read()
                    '''
                    content = re.sub(html_regex,'',content) #Deleting <....> HTML tags by replacing with ''
                    #print(content[0:1500])
                    print('----')

                    content = content.replace('&nbsp;','') #Deleting Breaking Space
                    #print(content[0:1500])
                    content = re.sub(r'&#\d+;', '', content) #Deleting &#9477 type of things
                
                    '''
                #with open(filenamewrite, 'w') as out_file:
                    #text = content.decode('utf-8')
                    #out_file.write(content)
                    
                    
                    matches_mda = re.findall(mda_regex, content, re.IGNORECASE | re.DOTALL | re.MULTILINE)
                    #print(matches_mda)
                    if matches_mda:
                        #print(cik)
                        #print(matches_mda)
                        #print('--'*100)
                        result = max(matches_mda, key=len)
                        result = str(result).replace('\n', '')
                        result = str(result).replace('\t', '')
                        #print(result)
                        resultdict['lp'] = [result]
                    else:
                        resultdict['lp'] = [""]
                    print(resultdict)
                    df_temp = pd.DataFrame.from_dict(resultdict)
                    df_final = df_final.append(df_temp,ignore_index=True)
                    
                in_file.close()

    return df_final

# %%
#inputDirectory = '/home/anuj/PycharmProjects/733/data_08032020/2018/10-K_clean'
inputDirectory = '/home/anuj/PycharmProjects/733/data_08042020/10-K_clean'
#masterFile = '/home/anuj/PycharmProjects/733/result_uncertain10mar.csv'
masterFile = "/home/anuj/PycharmProjects/733/cikfile_similarity.csv"
#outputDirectory = '/home/anuj/PycharmProjects/733/data/10-K_clean'
dataList = rawdata_extract( inputDirectory , masterFile)
#rawdata_extract( inputDirectory , masterFile, outputDirectory )
#print(dataList)
# Out:
# {'cik': [12927], 'company': ['BOEING CO'], 'date': ['2014-02-14'], 'path': ['edgar/data/12927/0000012927-14-000004.txt'], 'lp': ['item3 . legal proceedingscurrently , involved number legal proceedings . discussion contingencies related legal proceedings , see note 20to consolidated financial statements , hereby incorporated reference.item4 .']}
# {'cik': [12927], 'company': ['BOEING CO'], 'date': ['2019-02-08'], 'path': ['edgar/data/12927/0000012927-19-000010.txt'], 'lp': ['item3 . legal proceedingscurrently , involved number legal proceedings . discussion contingencies related legal proceedings , see note 22 consolidated financial statements , hereby incorporated reference.item4 .']}
# {'cik': [12927], 'company': ['BOEING CO'], 'date': ['2015-02-12'], 'path': ['edgar/data/12927/0000012927-15-000011.txt'], 'lp': ['item3 . legal proceedingscurrently , involved number legal proceedings . discussion contingencies related legal proceedings , see note 20to consolidated financial statements , hereby incorporated reference.item4 .']}
# {'cik': [12927], 'company': ['BOEING CO'], 'date': ['2016-02-10'], 'path': ['edgar/data/12927/0000012927-16-000099.txt'], 'lp': ['item3 . legal proceedingscurrently , involved number legal proceedings . discussion contingencies related legal proceedings , see note 20to consolidated financial statements , hereby incorporated reference.item4 .']}
# {'cik': [12927], 'company': ['BOEING CO'], 'date': ['2017-02-08'], 'path': ['edgar/data/12927/0000012927-17-000006.txt'], 'lp': ['item3 . legal proceedingscurrently , involved number legal proceedings . discussion contingencies related legal proceedings , see note 20to consolidated financial statements , hereby incorporated reference.item4 .']}
# {'cik': [12927], 'company': ['BOEING CO'], 'date': ['2018-02-12'], 'path': ['edgar/data/12927/0000012927-18-000007.txt'], 'lp': ['item3 . legal proceedingscurrently , involved number legal proceedings . discussion contingencies related legal proceedings , see note 20to consolidated financial statements , hereby incorporated reference.item4 .']}
# {'cik': [19617], 'company': ['JPMORGAN CHASE & CO'], 'date': ['2014-02-20'], 'path': ['edgar/data/19617/0000019617-14-000289.txt'], 'lp': ['item 3 : legal proceedingsfor description firms material legal proceedings , see note 31 pages 326332.item 4 ']}
# {'cik': [19617], 'company': ['JPMORGAN CHASE & CO'], 'date': ['2015-02-24'], 'path': ['edgar/data/19617/0000019617-15-000272.txt'], 'lp': ['item 3 : legal proceedingsfor description firms material legal proceedings , see note 31.item 4 ']}
# {'cik': [19617], 'company': ['JPMORGAN CHASE & CO'], 'date': ['2016-02-23'], 'path': ['edgar/data/19617/0000019617-16-000902.txt'], 'lp': ['item 3 : legal proceedingsfor description firms material legal proceedings , see note 31.item 4 ']}
# {'cik': [19617], 'company': ['JPMORGAN CHASE & CO'], 'date': ['2019-02-26'], 'path': ['edgar/data/19617/0000019617-19-000054.txt'], 'lp': ['item 3. legal proceedings.for description firms material legal proceedings , refer note 29.item 4.']}
# {'cik': [19617], 'company': ['JPMORGAN CHASE & CO'], 'date': ['2017-02-28'], 'path': ['edgar/data/19617/0000019617-17-000314.txt'], 'lp': ['item 3. legal proceedings.for description firms material legal proceedings , see note 31.item 4.']}
# {'cik': [19617], 'company': ['JPMORGAN CHASE & CO'], 'date': ['2018-02-27'], 'path': ['edgar/data/19617/0000019617-18-000057.txt'], 'lp': ['item 3. legal proceedings.for description firms material legal proceedings , see note 29.item 4.']}
# {'cik': [320193], 'company': ['APPLE INC'], 'date': ['2018-11-05'], 'path': ['edgar/data/320193/0000320193-18-000145.txt'], 'lp': ['item 3.legal proceedingsthe company subject legal proceedings claims fully resolved arisen ordinary course business . except described part ii , item 8 ']}
# {'cik': [320193], 'company': ['APPLE INC'], 'date': ['2016-10-26'], 'path': ['edgar/data/320193/0001628280-16-020309.txt'], 'lp': ['item 3. legal proceedingsthe company subject legal proceedings claims fully resolved arisen ordinary course business . opinion management , least reasonable possibility company may incurred material loss , material loss excess recorded accrual , respect loss contingencies asserted legal claims . however , outcome legal proceedings claims brought company subject significant uncertainty . therefore , although management considers likelihood outcome remote , one legal matters resolved company reporting period amounts excess managements expectations , companys consolidated financial statements reporting period could materially adversely affected . see risk factor company could impacted unfavorable results legal proceedings , found infringed intellectual property rights part , item1']}
# {'cik': [320193], 'company': ['APPLE INC'], 'date': ['2015-10-28'], 'path': ['edgar/data/320193/0001193125-15-356351.txt'], 'lp': ['item3 . legal proceedings company subject legal proceedings claims discussed well certain legal proceedings claims fully resolved arisen ordinary course business . opinion management , least reasonable possibility company may incurred material loss , material loss excess recorded accrual , respect loss contingencies asserted legal claims . however , outcome legal proceedings claims brought company subject significant uncertainty . therefore , although management considers likelihood outcome remote , one legal matters resolved company reporting period amounts excess managements expectations , companys consolidated financial statements reporting period could materially adversely affected . see risk factor company could impacted unfavorable results legal proceedings , found infringed intellectual property rights part , item1']}
# {'cik': [320193], 'company': ['APPLE INC'], 'date': ['2014-10-27'], 'path': ['edgar/data/320193/0001193125-14-383437.txt'], 'lp': ['item3 . legal proceedings company subject various legal proceedings claims discussed well certain legal proceedings claims fully resolved arisen ordinary course business . opinion management , least reasonable possibility company may incurred material loss , material loss excess recorded accrual , respect loss contingencies . however , outcome legal proceedings claims brought company subject significant uncertainty . therefore , although management considers likelihood outcome remote , one legal matters resolved company reporting period amounts excess managements expectations , companys consolidated financial statements reporting period could materially adversely affected . see risk factor company could impacted unfavorable results legal proceedings , found infringed intellectual property rights part , item1']}
# {'cik': [320193], 'company': ['APPLE INC'], 'date': ['2017-11-03'], 'path': ['edgar/data/320193/0000320193-17-000070.txt'], 'lp': ['item 3. legal proceedingsthe company subject legal proceedings claims fully resolved arisen ordinary course business . opinion management , least reasonable possibility company may incurred material loss , material loss excess recorded accrual , respect loss contingencies asserted legal claims . however , outcome legal proceedings claims brought company subject significant uncertainty . therefore , although management considers likelihood outcome remote , one legal matters resolved company reporting period amounts excess managements expectations , companys consolidated financial statements reporting period could materially adversely affected . see risk factor company could impacted unfavorable results legal proceedings , found infringed intellectual property rights part , item1']}
# {'cik': [320193], 'company': ['Apple Inc.'], 'date': ['2019-10-31'], 'path': ['edgar/data/320193/0000320193-19-000119.txt'], 'lp': ['item 3.legal proceedingsthe company subject legal proceedings claims fully resolved arisen ordinary course business . except described part ii , item 8 ']}

# %%
dataList['date'] =pd.to_datetime(dataList['date'])
dataList = dataList.sort_values(by=['cik','date'])

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
lemmatizer = WordNetLemmatizer()
similarity = []
soft_similarity = []

# %%
def jaccard_similarity(query, document):
        intersection = set(query).intersection(set(document))
        union = set(query).union(set(document))
        return len(intersection)/len(union)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

count_vectorizer1 = TfidfVectorizer()

# %%
def cosine_generator(coup_sent):
    sparse_matrix = count_vectorizer1.fit_transform(coup_sent)

# OPTIONAL: Convert Sparse Matrix to Pandas Dataframe if you want to see the word frequencies.
    doc_term_matrix = sparse_matrix.todense()
    df = pd.DataFrame(doc_term_matrix, 
                      columns=count_vectorizer1.get_feature_names(), 
                      index=['1', '2'])
    a = cosine_similarity(df, df)
    return(a[0][1])

# %%
# GENSIM
import gensim
# upgrade gensim if you can't import softcossim
from gensim.matutils import softcossim 
from gensim import corpora
import gensim.downloader as api
from gensim.utils import simple_preprocess

# Download the FastText model
#fasttext_model300 = api.load('fasttext-wiki-news-subwords-300')
fasttext_model300 = api.load('fasttext-wiki-news-subwords-300')

# %%
def softcosine_generator(coup_sent):
    dictionary = corpora.Dictionary([simple_preprocess(doc) for doc in coup_sent])

# Prepare the similarity matrix
    similarity_matrix = fasttext_model300.similarity_matrix(dictionary, tfidf=None, threshold=0.0, exponent=2.0, nonzero_limit=100)

# Convert the sentences into bag-of-words vectors.
    sent_1 = dictionary.doc2bow(simple_preprocess(coup_sent[0]))
    sent_2 = dictionary.doc2bow(simple_preprocess(coup_sent[1]))
    
    return (softcossim(sent_1, sent_2, similarity_matrix))

#sentences = [sent_1, sent_2]

# %%
df_final_similarity = pd.DataFrame()
cik_value = [320193,19617,12927]
for i in cik_value:
    temp_df = dataList[dataList['cik'] == i]
    temp_dict = {}
    
    for i in range(5):
        list_str = [temp_df.iloc[i,4],temp_df.iloc[i+1,4]]
        temp_dict['cik'] = [temp_df.iloc[i,0]]
        temp_dict['company'] = [temp_df.iloc[i,1]]
        temp_dict['date'] = [temp_df.iloc[i+1,2]]
        coup_sent = []
        for i in range(len(list_str)):
            #print(list_str[i])
            #print('-------------------')
            words = nltk.word_tokenize(list_str[i])
            words = [lemmatizer.lemmatize(word) for word in words]
            sent = ' '.join(words)
            
            coup_sent.append(sent)
        #sim_score = jaccard_similarity(coup_sent[0],coup_sent[1])
        #[0.8666666666666667, 1.0, 1.0, 1.0, 0.8666666666666667, 0.8666666666666667, 1.0, 1.0, 1.0, 0.8666666666666667]
        
        sim_score = cosine_generator(coup_sent)
        #[0.44066352960318245, 0.9621651214999738, 0.9874426697380431, 0.9523528992672959, 0.44066352960318245]
        temp_dict['cosine_similar'] = [sim_score]
        softsim_score = softcosine_generator(coup_sent)
        temp_dict['gensim_similar'] = [softsim_score]
        #[0.6412587091765587, 0.9857519524291879, 0.9925883778299979, 0.9815659501105083, 0.6412586811273455]
        
        #similarity.append(sim_score)
        #soft_similarity.append(softsim_score)
        df_temp_similarity = pd.DataFrame.from_dict(temp_dict)
        df_final_similarity = df_final_similarity.append(df_temp_similarity,ignore_index=True)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similarity_matrix` (Method will be removed in 4.0.0, use gensim.models.keyedvectors.WordEmbeddingSimilarityIndex instead).
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `softcossim` (Function will be removed in 4.0.0, use gensim.similarities.termsim.SparseTermSimilarityMatrix.inner_product instead).
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similarity_matrix` (Method will be removed in 4.0.0, use gensim.models.keyedvectors.WordEmbeddingSimilarityIndex instead).
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `softcossim` (Function will be removed in 4.0.0, use gensim.similarities.termsim.SparseTermSimilarityMatrix.inner_product instead).
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similarity_matrix` (Method will be removed in 4.0.0, use gensim.models.keyedvectors.WordEmbeddingSimilarityIndex instead).
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `softcossim` (Function will be removed in 4.0.0, use gensim.similarities.termsim.SparseTermSimilarityMatrix.inner_product instead).
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similarity_matrix` (Method will be removed in 4.0.0, use gensim.models.keyedvectors.WordEmbeddingSimilarityIndex instead).
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `softcossim` (Function will be removed in 4.0.0, use gensim.similarities.termsim.SparseTermSimilarityMatrix.inner_product instead).
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similarity_matrix` (Method will be removed in 4.0.0, use gensim.models.keyedvectors.WordEmbeddingSimilarityIndex instead).
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `softcossim` (Function will be removed in 4.0.0, use gensim.similarities.termsim.SparseTermSimilarityMatrix.inner_product instead).
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similarity_matrix` (Method will be removed in 4.0.0, use gensim.models.keyedvectors.WordEmbeddingSimilarityIndex instead).
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `softcossim` (Function will be removed in 4.0.0, use gensim.similarities.termsim.SparseTermSimilarityMatrix.inner_product instead).
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similarity_matrix` (Method will be removed in 4.0.0, use gensim.models.keyedvectors.WordEmbeddingSimilarityIndex instead).
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `softcossim` (Function will be removed in 4.0.0, use gensim.similarities.termsim.SparseTermSimilarityMatrix.inner_product instead).
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similarity_matrix` (Method will be removed in 4.0.0, use gensim.models.keyedvectors.WordEmbeddingSimilarityIndex instead).
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `softcossim` (Function will be removed in 4.0.0, use gensim.similarities.termsim.SparseTermSimilarityMatrix.inner_product instead).
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similarity_matrix` (Method will be removed in 4.0.0, use gensim.models.keyedvectors.WordEmbeddingSimilarityIndex instead).
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `softcossim` (Function will be removed in 4.0.0, use gensim.similarities.termsim.SparseTermSimilarityMatrix.inner_product instead).
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similarity_matrix` (Method will be removed in 4.0.0, use gensim.models.keyedvectors.WordEmbeddingSimilarityIndex instead).
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `softcossim` (Function will be removed in 4.0.0, use gensim.similarities.termsim.SparseTermSimilarityMatrix.inner_product instead).
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similarity_matrix` (Method will be removed in 4.0.0, use gensim.models.keyedvectors.WordEmbeddingSimilarityIndex instead).
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `softcossim` (Function will be removed in 4.0.0, use gensim.similarities.termsim.SparseTermSimilarityMatrix.inner_product instead).
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similarity_matrix` (Method will be removed in 4.0.0, use gensim.models.keyedvectors.WordEmbeddingSimilarityIndex instead).
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `softcossim` (Function will be removed in 4.0.0, use gensim.similarities.termsim.SparseTermSimilarityMatrix.inner_product instead).
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similarity_matrix` (Method will be removed in 4.0.0, use gensim.models.keyedvectors.WordEmbeddingSimilarityIndex instead).
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `softcossim` (Function will be removed in 4.0.0, use gensim.similarities.termsim.SparseTermSimilarityMatrix.inner_product instead).
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similarity_matrix` (Method will be removed in 4.0.0, use gensim.models.keyedvectors.WordEmbeddingSimilarityIndex instead).
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `softcossim` (Function will be removed in 4.0.0, use gensim.similarities.termsim.SparseTermSimilarityMatrix.inner_product instead).
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similarity_matrix` (Method will be removed in 4.0.0, use gensim.models.keyedvectors.WordEmbeddingSimilarityIndex instead).
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `softcossim` (Function will be removed in 4.0.0, use gensim.similarities.termsim.SparseTermSimilarityMatrix.inner_product instead).
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_final_similarity
# Out:
#        cik              company       date  cosine_similar  gensim_similar
# 0   320193            APPLE INC 2015-10-28        0.987443        0.992588
# 1   320193            APPLE INC 2016-10-26        0.962165        0.985752
# 2   320193            APPLE INC 2017-11-03        1.000000        1.000000
# 3   320193            APPLE INC 2018-11-05        0.440664        0.641259
# 4   320193            APPLE INC 2019-10-31        1.000000        1.000000
# 5    19617  JPMORGAN CHASE & CO 2015-02-24        0.895532        0.969658
# 6    19617  JPMORGAN CHASE & CO 2016-02-23        1.000000        1.000000
# 7    19617  JPMORGAN CHASE & CO 2017-02-28        0.836315        0.912573
# 8    19617  JPMORGAN CHASE & CO 2018-02-27        0.890109        1.000000
# 9    19617  JPMORGAN CHASE & CO 2019-02-26        0.890109        0.964975
# 10   12927            BOEING CO 2015-02-12        1.000000        1.000000
# 11   12927            BOEING CO 2016-02-10        1.000000        1.000000
# 12   12927            BOEING CO 2017-02-08        1.000000        1.000000
# 13   12927            BOEING CO 2018-02-12        1.000000        1.000000
# 14   12927            BOEING CO 2019-02-08        0.936229        0.987462
