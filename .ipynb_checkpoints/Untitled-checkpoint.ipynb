# %%
import pandas as pd
from sqlalchemy import create_engine
from yahoofinancials import YahooFinancials
from datetime import date

# %%
data = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
table = data[0]

table1 = table[1:]

sp_list = table1[['Symbol','Security','GICS Sector','CIK']]
sp_list = sp_list.rename(columns={'Symbol': 'symbol', 'Security': 'company_name','GICS Sector': 'sector','CIK' : 'cik'})

engine = create_engine('postgresql://postgres:postgres@localhost:5432/stocks')
sp_list.to_sql('company_info', con=engine)

# %%
import json
engine = create_engine('postgresql://postgres:postgres@localhost:5432/stocks')
df = pd.read_sql_query('select symbol,cik,company_name from "company_info"',con=engine)
#print(df['symbol'].head(10))
#symbols = df['symbol'].tolist()
#print(symbols)
symbols = ['AAPL','BA','JPM']
yahoo_financials_tech = YahooFinancials(symbols)

daily_stocks_prices = yahoo_financials_tech.get_historical_price_data('2010-01-01','2019-12-31', 'daily')
print(daily_stocks_prices)
for symbol in symbols:
    try:
        print(symbol)
        prices_list = daily_stocks_prices.get(symbol).get("prices")
        
        df_prices = pd.DataFrame.from_dict(prices_list)
        df_prices['cik'] = cik.values[0]
        
        
        df_prices['symbol'] = symbol
        df_prices['company_name'] = company_name.values[0]
        
        
        df_prices = df_prices[['high','low','open','close','volume','formatted_date']]
        
        subsetDataFrame = df[df['symbol'] == symbol]
        
        company_name = subsetDataFrame['company_name']
        cik = subsetDataFrame['cik']
        
        #df_prices['year'] = pd.to_datetime(df_prices['formatted_date']).dt.year
        
               
        print(df_prices.head(10))
        
        df_prices.to_sql('stocks_prices_1', con=engine,if_exists='append',index=False)
    except:
        pass
# Out:
# {'AAPL': {'eventsData': {'dividends': {'2016-11-03': {'amount': 0.57, 'date': 1478179800, 'formatted_date': '2016-11-03'}, '2017-05-11': {'amount': 0.63, 'date': 1494509400, 'formatted_date': '2017-05-11'}, '2018-11-08': {'amount': 0.73, 'date': 1541687400, 'formatted_date': '2018-11-08'}, '2019-05-10': {'amount': 0.77, 'date': 1557495000, 'formatted_date': '2019-05-10'}, '2013-11-06': {'amount': 0.43571, 'date': 1383748200, 'formatted_date': '2013-11-06'}, '2013-05-09': {'amount': 0.43571, 'date': 1368106200, 'formatted_date': '2013-05-09'}, '2015-05-07': {'amount': 0.52, 'date': 1431005400, 'formatted_date': '2015-05-07'}, '2015-11-05': {'amount': 0.52, 'date': 1446733800, 'formatted_date': '2015-11-05'}, '2017-08-10': {'amount': 0.63, 'date': 1502371800, 'formatted_date': '2017-08-10'}, '2018-02-09': {'amount': 0.63, 'date': 1518186600, 'formatted_date': '2018-02-09'}, '2019-08-09': {'amount': 0.77, 'date': 1565357400, 'formatted_date': '2019-08-09'}, '2013-08-08': {'amount': 0.43571, 'date': 1375968600, 'formatted_date': '2013-08-08'}, '2014-02-06': {'amount': 0.43571, 'date': 1391697000, 'formatted_date': '2014-02-06'}, '2015-08-06': {'amount': 0.52, 'date': 1438867800, 'formatted_date': '2015-08-06'}, '2016-02-04': {'amount': 0.52, 'date': 1454596200, 'formatted_date': '2016-02-04'}, '2019-11-07': {'amount': 0.77, 'date': 1573137000, 'formatted_date': '2019-11-07'}, '2017-11-10': {'amount': 0.63, 'date': 1510324200, 'formatted_date': '2017-11-10'}, '2018-05-11': {'amount': 0.73, 'date': 1526045400, 'formatted_date': '2018-05-11'}, '2012-11-07': {'amount': 0.37857, 'date': 1352298600, 'formatted_date': '2012-11-07'}, '2014-05-08': {'amount': 0.47, 'date': 1399555800, 'formatted_date': '2014-05-08'}, '2014-11-06': {'amount': 0.47, 'date': 1415284200, 'formatted_date': '2014-11-06'}, '2016-05-05': {'amount': 0.57, 'date': 1462455000, 'formatted_date': '2016-05-05'}, '2017-02-09': {'amount': 0.57, 'date': 1486650600, 'formatted_date': '2017-02-09'}, '2018-08-10': {'amount': 0.73, 'date': 1533907800, 'formatted_date': '2018-08-10'}, '2019-02-08': {'amount': 0.73, 'date': 1549636200, 'formatted_date': '2019-02-08'}, '2012-08-09': {'amount': 0.37857, 'date': 1344519000, 'formatted_date': '2012-08-09'}, '2013-02-07': {'amount': 0.37857, 'date': 1360247400, 'formatted_date': '2013-02-07'}, '2014-08-07': {'amount': 0.47, 'date': 1407418200, 'formatted_date': '2014-08-07'}, '2015-02-05': {'amount': 0.47, 'date': 1423146600, 'formatted_date': '2015-02-05'}, '2016-08-04': {'amount': 0.57, 'date': 1470317400, 'formatted_date': '2016-08-04'}}, 'splits': {'2014-06-09': {'date': 1402320600, 'numerator': 7, 'denominator': 1, 'splitRatio': '7:1', 'formatted_date': '2014-06-09'}}}, 'firstTradeDate': {'formatted_date': '1980-12-12', 'date': 345459600}, 'currency': 'USD', 'instrumentType': 'EQUITY', 'timeZone': {'gmtOffset': -14400}, 'prices': [{'date': 1262615400, 'high': 30.64285659790039, 'low': 30.34000015258789, 'open': 30.489999771118164, 'close': 30.572856903076172, 'volume': 123432400, 'adjclose': 26.538482666015625, 'formatted_date': '2010-01-04'}, {'date': 1262701800, 'high': 30.79857063293457, 'low': 30.464284896850586, 'open': 30.657142639160156, 'close': 30.625713348388672, 'volume': 150476200, 'adjclose': 26.584365844726562, 'formatted_date': '2010-01-05'}, {'date': 1262788200, 'high': 30.747142791748047, 'low': 30.10714340209961, 'open': 30.625713348388672, 'close': 30.13857078552246, 'volume': 138040000, 'adjclose': 26.161508560180664, 'formatted_date': '2010-01-06'}, {'date': 1262874600, 'high': 30.285715103149414, 'low': 29.864286422729492, 'open': 30.25, 'close': 30.082857131958008, 'volume': 119282800, 'adjclose': 26.11314582824707, 'formatted_date': '2010-01-07'}, {'date': 1262961000, 'high': 30.285715103149414, 'low': 29.86571502685547, 'open': 30.042856216430664, 'close': 30.28285789489746, 'volume': 111902700, 'adjclose': 26.286752700805664, 'formatted_date': '2010-01-08'}, {'date': 1263220200, 'high': 30.4285717010498 ...
# AAPL
#         high        low       open      close     volume formatted_date  \
# 0  30.642857  30.340000  30.490000  30.572857  123432400     2010-01-04
# 1  30.798571  30.464285  30.657143  30.625713  150476200     2010-01-05
# 2  30.747143  30.107143  30.625713  30.138571  138040000     2010-01-06
# 3  30.285715  29.864286  30.250000  30.082857  119282800     2010-01-07
# 4  30.285715  29.865715  30.042856  30.282858  111902700     2010-01-08
# 5  30.428572  29.778572  30.400000  30.015715  115557400     2010-01-11
